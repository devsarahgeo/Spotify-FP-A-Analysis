# %%
import boto3
import json
import os
import pandas as pd

# %% [markdown]
# #### Data Quality & Exploration Insights:
#
# - Identified missing values in all playlist_details columns due to API rate limit(these values were not filled). Approximately 200 incomplete records were removed via dbt to ensure clean analysis.
#
# - Detected and removed duplicate records via dbt across multiple tables to maintain data integrity.
#
# - Explored relationships between playlist metrics: playlists with more tracks tend to have slightly higher follower counts, though the correlation is weak.
#
# - Noted extreme values in podcast data—for example, some shows like IHeartRadio have over 10,000 episodes—highlighting the need for careful aggregation in analyses.
#
# - NOTE : There is 1 artist named 'rock' which has diff artist id's but same artist name. Means they are different artists with the same name

# %%
s3 = boto3.client(
    "s3",
    region_name="us-east-1",
    aws_access_key_id=os.getenv("AWS_ACCESS_KEY_ID"),
    aws_secret_access_key=os.getenv("AWS_SECRET_ACCESS_KEY")
)

bucket = "fpa-analysis"
keys = ["tracks.json", "playlists.json", "artists.json", "podcasts.json", "new_releases.json", "playlist_details.json", "podcast_details.json"]

data_frames = {}

for key in keys:
    # Fetch object from S3
    obj = s3.get_object(Bucket=bucket, Key=key)
    file_content = obj['Body'].read().decode('utf-8')

    # Handle JSON
    data = []
    for line in file_content.splitlines():
        if line.strip():  # skip empty lines
            data.append(json.loads(line))

    # Convert to DataFrame
    df = pd.DataFrame(data)
    
    # Store in dictionary with key name
    data_frames[key] = df

    print(f"{key}: Loaded {len(df)} records")

tracks_df = data_frames["tracks.json"]
playlists_df = data_frames["playlists.json"]
artists_df = data_frames["artists.json"]
podcasts_df = data_frames["podcasts.json"]
new_releases_df = data_frames["new_releases.json"]
playlist_details_df = data_frames["playlist_details.json"]
podcast_details_df = data_frames["podcast_details.json"]

tracks_df.head()
# Out:
# tracks.json: Loaded 1000 records
# playlists.json: Loaded 854 records
# artists.json: Loaded 1028 records
# podcasts.json: Loaded 3000 records
# new_releases.json: Loaded 100 records
# playlist_details.json: Loaded 854 records
# podcast_details.json: Loaded 1169 records
#                                                album  \
# 0  {'album_type': 'compilation', 'artists': [{'ex...
# 1  {'album_type': 'album', 'artists': [{'external...
# 2  {'album_type': 'album', 'artists': [{'external...
# 3  {'album_type': 'album', 'artists': [{'external...
# 4  {'album_type': 'compilation', 'artists': [{'ex...
#
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 1  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 2  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 3  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 4  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
#
#    duration_ms  explicit              external_ids  \
# 0       268413     False  {'isrc': 'USWD10527739'}
# 1       314280      True  {'isrc': 'USUM71502773'}
# 2       323962      True  {'isrc': 'USRC11500797'}
# 3       145052     False  {'isrc': 'QZW9K2521015'}
# 4       181013     False  {'isrc': 'USWD10935873'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/5a...
# 1  {'spotify': 'https://open.spotify.com/track/06...
# 2  {'spotify': 'https://open.spotify.com/track/2g...
# 3  {'spotify': 'https://open.spotify.com/track/7J...
# 4  {'spotify': 'https://open.spotify.com/track/6n...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/5aNagthlHAud...  5aNagthlHAudbDZozQMjYP
# 1  https://api.spotify.com/v1/tracks/069VGijrAsQV...  069VGijrAsQVSY9ihFv1Px
# 2  https://api.spotify.com/v1/tracks/2gAGWaK4wvt2...  2gAGWaK4wvt2xrFUlR4mK8
# 3  https://api.spotify.com/v1/tracks/7JQFjUucD7QP...  7JQFjUucD7QPhPnaPxTDBc
# 4  https://api.spotify.com/v1/tracks/6ntkwU1MhehT...  6ntkwU1MhehTKgx4BWxX3f
#
#    is_local  is_playable                                         name  \
# 0     False         True                      Stick to the Status Quo
# 1     False         True                                  Best Friend
# 2     False         True  Jukebox Joints (feat. Joe Fox & Kanye West)
# 3     False         True                               SATURACIÓN POP
# 4     False         True                            Hoedown Throwdown
#
#    popularity preview_url  track_number   type  \
# 0          60        None             5  track
# 1          62        None             8  track
# 2          75        None             9  track
# 3          58        None             1  track
# 4          58        None             6  track
#
#                                     uri                 query
# 0  spotify:track:5aNagthlHAudbDZozQMjYP  [pop, rock, hip-hop]
# 1  spotify:track:069VGijrAsQVSY9ihFv1Px  [pop, rock, hip-hop]
# 2  spotify:track:2gAGWaK4wvt2xrFUlR4mK8  [pop, rock, hip-hop]
# 3  spotify:track:7JQFjUucD7QPhPnaPxTDBc  [pop, rock, hip-hop]
# 4  spotify:track:6ntkwU1MhehTKgx4BWxX3f  [pop, rock, hip-hop]

# %%
# shape chk
for name, df in data_frames.items():
    print(f"{name}: {df.shape}")
    df.head(3)
# Out:
# tracks.json: (1000, 19)
# playlists.json: (854, 15)
# artists.json: (1028, 10)
# podcasts.json: (3000, 18)
# new_releases.json: (100, 13)
# playlist_details.json: (854, 16)
# podcast_details.json: (1169, 18)

# %%
# missing values
for name, df in data_frames.items():
    print(f"Missing values in {name}:")
    print(df.isna().sum())
# Out:
# Missing values in tracks.json:
# album                   0
# artists                 0
# available_markets       0
# disc_number             0
# duration_ms             0
# explicit                0
# external_ids            0
# external_urls           0
# href                    0
# id                      0
# is_local                0
# is_playable             0
# name                    0
# popularity              0
# preview_url          1000
# track_number            0
# type                    0
# uri                     0
# query                   0
# dtype: int64
# Missing values in playlists.json:
# collaborative      0
# description        0
# external_urls      0
# href               0
# id                 0
# images             0
# name               0
# owner              0
# primary_color    854
# public             0
# snapshot_id        0
# tracks             0
# type               0
# uri                0
# query              0
# dtype: int64
# Missing values in artists.json:
# external_urls    0
# followers        0
# genres           0
# href             0
# id               0
# images           0
# name             0
# popularity       0
# type             0
# uri              0
# dtype: int64
# Missing values in podcasts.json:
# available_markets        0
# copyrights               0
# description              0
# html_description         0
# explicit                 0
# external_urls            0
# href                     0
# id                       0
# images                   0
# is_externally_hosted     0
# languages                0
# media_type               0
# name                     0
# publisher                0
# type                     0
# uri                      0
# total_episodes          50
# query                    0
# dtype: int64
# Missing values in new_releases.json:
# album_type                0
# artists                   0
# available_markets         0
# external_urls             0
# href                      0
# id                        0
# images                    0
# name                      0
# release_date              0
# release_date_precision    0
# total_tracks              0
# type                      0
# uri                       0
# dtype: int64
# Missing values in playlist_details.json:
# collaborative    267
# description      267
# external_urls    267
# followers        267
# href             267
# id               267
# images           267
# name             267
# owner            267
# primary_color    854
# public           267
# snapshot_id      267
# tracks           267
# type             267
# uri              267
# error            587
# dtype: int64
# Missing values in podcast_details.json:
# available_markets       0
# copyrights              0
# description             0
# html_description        0
# explicit                0
# external_urls           0
# href                    0
# id                      0
# images                  0
# is_externally_hosted    0
# languages               0
# media_type              0
# name                    0
# publisher               0
# type                    0
# uri                     0
# total_episodes          0
# episodes                0
# dtype: int64

# %%
playlist_details_df.isna().sum()
# Out:
# collaborative      267
# description        267
# external_urls      267
# followers          267
# href               267
# id                 267
# images             267
# name               267
# owner              267
# primary_color      854
# public             267
# snapshot_id        267
# tracks             267
# type               267
# uri                267
# error              587
# followers_total      0
# dtype: int64

# %%
playlist_details_df[playlist_details_df["collaborative"].isna()].head()

# drop these null rows, its because of api rate limit - > dropped via bigquery
# Out:
#     collaborative description external_urls followers href   id images name  \
# 95            NaN         NaN           NaN       NaN  NaN  NaN    NaN  NaN
# 96            NaN         NaN           NaN       NaN  NaN  NaN    NaN  NaN
# 99            NaN         NaN           NaN       NaN  NaN  NaN    NaN  NaN
# 101           NaN         NaN           NaN       NaN  NaN  NaN    NaN  NaN
# 102           NaN         NaN           NaN       NaN  NaN  NaN    NaN  NaN
#
#     owner  primary_color public snapshot_id tracks type  uri  \
# 95    NaN            NaN    NaN         NaN    NaN  NaN  NaN
# 96    NaN            NaN    NaN         NaN    NaN  NaN  NaN
# 99    NaN            NaN    NaN         NaN    NaN  NaN  NaN
# 101   NaN            NaN    NaN         NaN    NaN  NaN  NaN
# 102   NaN            NaN    NaN         NaN    NaN  NaN  NaN
#
#                                                  error  followers_total
# 95   {'status': 429, 'message': 'API rate limit exc...                0
# 96   {'status': 429, 'message': 'API rate limit exc...                0
# 99   {'status': 429, 'message': 'API rate limit exc...                0
# 101  {'status': 429, 'message': 'API rate limit exc...                0
# 102  {'status': 429, 'message': 'API rate limit exc...                0

# %%
tracks_df[tracks_df["id"] == "52IuMfbQa9aqRPz2oYPAI8"].head()
# Out:
#                                                  album  \
# 53   {'album_type': 'album', 'artists': [{'external...
# 105  {'album_type': 'album', 'artists': [{'external...
#
#                                                artists  \
# 53   [{'external_urls': {'spotify': 'https://open.s...
# 105  [{'external_urls': {'spotify': 'https://open.s...
#
#                                      available_markets  disc_number  \
# 53   [AG, AL, AM, AO, AZ, BB, BF, BI, BJ, BN, BS, B...            1
# 105  [AG, AL, AM, AO, AZ, BB, BF, BI, BJ, BN, BS, B...            1
#
#      duration_ms  explicit              external_ids  \
# 53        265101      True  {'isrc': 'USPO10000879'}
# 105       265101      True  {'isrc': 'USPO10000879'}
#
#                                          external_urls  \
# 53   {'spotify': 'https://open.spotify.com/track/52...
# 105  {'spotify': 'https://open.spotify.com/track/52...
#
#                                                   href  \
# 53   https://api.spotify.com/v1/tracks/52IuMfbQa9aq...
# 105  https://api.spotify.com/v1/tracks/52IuMfbQa9aq...
#
#                          id  is_local  is_playable              name  \
# 53   52IuMfbQa9aqRPz2oYPAI8     False         True  Express Yourself
# 105  52IuMfbQa9aqRPz2oYPAI8     False         True  Express Yourself
#
#      popularity preview_url  track_number   type  \
# 53           61        None             8  track
# 105          61        None             8  track
#
#                                       uri                 query
# 53   spotify:track:52IuMfbQa9aqRPz2oYPAI8  [pop, rock, hip-hop]
# 105  spotify:track:52IuMfbQa9aqRPz2oYPAI8  [pop, rock, hip-hop]

# %%
# duplicates

for name, df in data_frames.items():
    if 'id' in df.columns:
        print(f"Duplicates in {name}: {df.duplicated(subset=['id']).sum()}")
    else:
        print(f"{name} has no 'id' column, skipping duplicate check")
# Out:
# Duplicates in tracks.json: 109
# Duplicates in playlists.json: 267
# Duplicates in artists.json: 0
# Duplicates in podcasts.json: 416
# Duplicates in new_releases.json: 0
# Duplicates in playlist_details.json: 411
# Duplicates in podcast_details.json: 46

# %%
podcast_details_df.head()
# Out:
#                                    available_markets copyrights  \
# 0  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...         []
# 1  [AD, AE, AG, AL, AM, AR, AT, AU, BA, BB, BE, B...         []
# 2  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...         []
# 3  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...         []
# 4  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...         []
#
#                                          description  \
# 0  Listen for a comprehensive audio report on tod...
# 1  Covering Geopolitical News from around the world.
# 2  Seeking Alpha's flagship Wall Street Breakfast...
# 3  Business of Home's host Dennis Scully intervie...
# 4  Learn how companies work from the people who k...
#
#                                     html_description  explicit  \
# 0  <p>Listen for a comprehensive audio report on ...     False
# 1  Covering Geopolitical News from around the world.      True
# 2  Seeking Alpha&#39;s flagship Wall Street Break...     False
# 3  Business of Home&#39;s host Dennis Scully inte...     False
# 4  <p>Learn how companies work from the people wh...     False
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/show/5q8...
# 1  {'spotify': 'https://open.spotify.com/show/1Tm...
# 2  {'spotify': 'https://open.spotify.com/show/05u...
# 3  {'spotify': 'https://open.spotify.com/show/44R...
# 4  {'spotify': 'https://open.spotify.com/show/417...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/shows/5q8wg5rFYbbeD...  5q8wg5rFYbbeDk0kk7t6Uc
# 1  https://api.spotify.com/v1/shows/1Tm6Snolm6lrP...  1Tm6Snolm6lrPhqJcbaYTt
# 2  https://api.spotify.com/v1/shows/05uLjJxkVgQsR...  05uLjJxkVgQsRk8LWLCLpx
# 3  https://api.spotify.com/v1/shows/44REgaXjBseF4...  44REgaXjBseF4ZanktPyjL
# 4  https://api.spotify.com/v1/shows/417NPBWqtMbDU...  417NPBWqtMbDU0FlWZTRDC
#
#                                               images  is_externally_hosted  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 False
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 False
# 2  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 False
# 3  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 False
# 4  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 False
#
#   languages media_type                      name  \
# 0   [en-US]      audio        Bloomberg News Now
# 1      [en]      mixed           Business Basics
# 2      [en]      audio     Wall Street Breakfast
# 3      [en]      audio  Business of Home Podcast
# 4      [en]      mixed       Business Breakdowns
#
#                                   publisher  type  \
# 0                                 Bloomberg  show
# 1                           Business Basics  show
# 2                             Seeking Alpha  show
# 3           Business of Home, Dennis Scully  show
# 4  Colossus | Investing & Business Podcasts  show
#
#                                    uri  total_episodes  \
# 0  spotify:show:5q8wg5rFYbbeDk0kk7t6Uc             901
# 1  spotify:show:1Tm6Snolm6lrPhqJcbaYTt             326
# 2  spotify:show:05uLjJxkVgQsRk8LWLCLpx            1000
# 3  spotify:show:44REgaXjBseF4ZanktPyjL             528
# 4  spotify:show:417NPBWqtMbDU0FlWZTRDC             251
#
#                                             episodes
# 0  {'href': 'https://api.spotify.com/v1/shows/5q8...
# 1  {'href': 'https://api.spotify.com/v1/shows/1Tm...
# 2  {'href': 'https://api.spotify.com/v1/shows/05u...
# 3  {'href': 'https://api.spotify.com/v1/shows/44R...
# 4  {'href': 'https://api.spotify.com/v1/shows/417...

# %%
# data types

for name, df in data_frames.items():
    print(f"Data types in {name}:")
    print(df.dtypes)
# Out:
# Data types in tracks.json:
# album                object
# artists              object
# available_markets    object
# disc_number           int64
# duration_ms           int64
# explicit               bool
# external_ids         object
# external_urls        object
# href                 object
# id                   object
# is_local               bool
# is_playable            bool
# name                 object
# popularity            int64
# preview_url          object
# track_number          int64
# type                 object
# uri                  object
# query                object
# dtype: object
# Data types in playlists.json:
# collaborative      bool
# description      object
# external_urls    object
# href             object
# id               object
# images           object
# name             object
# owner            object
# primary_color    object
# public             bool
# snapshot_id      object
# tracks           object
# type             object
# uri              object
# query            object
# dtype: object
# Data types in artists.json:
# external_urls    object
# followers        object
# genres           object
# href             object
# id               object
# images           object
# name             object
# popularity        int64
# type             object
# uri              object
# dtype: object
# Data types in podcasts.json:
# available_markets        object
# copyrights               object
# description              object
# html_description         object
# explicit                   bool
# external_urls            object
# href                     object
# id                       object
# images                   object
# is_externally_hosted       bool
# languages                object
# media_type               object
# name                     object
# publisher                object
# type                     object
# uri                      object
# total_episodes          float64
# query                    object
# dtype: object
# Data types in new_releases.json:
# album_type                object
# artists                   object
# available_markets         object
# external_urls             object
# href                      object
# id                        object
# images                    object
# name                      object
# release_date              object
# release_date_precision    object
# total_tracks               int64
# type                      object
# uri                       object
# dtype: object
# Data types in playlist_details.json:
# collaborative     object
# description       object
# external_urls     object
# followers         object
# href              object
# id                object
# images            object
# name              object
# owner             object
# primary_color    float64
# public            object
# snapshot_id       object
# tracks            object
# type              object
# uri               object
# error             object
# dtype: object
# Data types in podcast_details.json:
# available_markets       object
# copyrights              object
# description             object
# html_description        object
# explicit                  bool
# external_urls           object
# href                    object
# id                      object
# images                  object
# is_externally_hosted      bool
# languages               object
# media_type              object
# name                    object
# publisher               object
# type                    object
# uri                     object
# total_episodes           int64
# episodes                object
# dtype: object

# %%
# summary stats

for name, df in data_frames.items():
    print(f"Summary of numeric columns in {name}:")
    print(df.describe())
# Out:
# Summary of numeric columns in tracks.json:
#        disc_number   duration_ms   popularity  track_number
# count  1000.000000  1.000000e+03  1000.000000   1000.000000
# mean      1.014000  2.165711e+05    30.776000      5.335000
# std       0.140797  1.012247e+05    18.781229      5.624092
# min       1.000000  3.078300e+04     0.000000      1.000000
# 25%       1.000000  1.645710e+05    12.000000      1.000000
# 50%       1.000000  2.050065e+05    34.500000      3.000000
# 75%       1.000000  2.503710e+05    44.000000      8.000000
# max       4.000000  1.300000e+06    76.000000     56.000000
# Summary of numeric columns in playlists.json:
#        collaborative description  \
# count            854         854
# unique             2         369
# top            False
# freq             852         307
#
#                                             external_urls  \
# count                                                 854
# unique                                                587
# top     {'spotify': 'https://open.spotify.com/playlist...
# freq                                                    4
#
#                                                      href  \
# count                                                 854
# unique                                                587
# top     https://api.spotify.com/v1/playlists/4ASGb9HSo...
# freq                                                    4
#
#                             id  \
# count                      854
# unique                     587
# top     4ASGb9HSoMEUekd7ClxZxZ
# freq                         4
#
#                                                    images     name  \
# count                                                 854      854
# unique                                                585      569
# top     [{'height': None, 'url': 'https://image-cdn-ak...  Hip-Hop
# freq                                                    4       13
#
#                                                     owner primary_color  \
# count                                                 854             0
# unique                                                541             0
# top     {'display_name': 'Ícones do Rock Brasileiro', ...           NaN
# freq                                                   10           NaN
#
#        public                       snapshot_id  \
# count     854                               854
# unique      1                               587
# top      True  AAAD2pU2CPk9ip0Z6Jv/7k5uEAE39TI1
# freq      854                                 4
#
#                                                    tracks      type  \
# count                                                 854       854
# unique                                                587         1
# top     {'href': 'https://api.spotify.com/v1/playlists...  playlist
# freq                                                    4       854
#
#                                             uri query
# count                                       854   854
# unique                                      587     3
# top     spotify:playlist:4ASGb9HSoMEUekd7ClxZxZ  rock
# freq                                          4   727
# Summary of numeric columns in artists.json:
#         popularity
# count  1028.000000
# mean     41.930934
# std      21.537452
# min       0.000000
# 25%      28.000000
# 50%      43.000000
# 75%      58.250000
# max      96.000000
# Summary of numeric columns in podcasts.json:
#        total_episodes
# count     2950.000000
# mean       347.038644
# std        667.092168
# min          1.000000
# 25%         36.000000
# 50%        132.000000
# 75%        384.000000
# max      10958.000000
# Summary of numeric columns in new_releases.json:
#        total_tracks
# count    100.000000
# mean       6.550000
# std        7.709859
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%       11.250000
# max       35.000000
# Summary of numeric columns in playlist_details.json:
#        primary_color
# count            0.0
# mean             NaN
# std              NaN
# min              NaN
# 25%              NaN
# 50%              NaN
# 75%              NaN
# max              NaN
# Summary of numeric columns in podcast_details.json:
#        total_episodes
# count     1169.000000
# mean       340.141146
# std        560.748349
# min          1.000000
# 25%         37.000000
# 50%        132.000000
# 75%        373.000000
# max       5153.000000

# %%
podcasts_df[podcasts_df["total_episodes"] > 10000].head()
# Out:
#                                       available_markets copyrights  \
# 2261  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...         []
#
#                                             description  \
# 2261  Brooke & Jeffrey in the Morning is a nationall...
#
#                                        html_description  explicit  \
# 2261  <p>Brooke &amp; Jeffrey in the Morning is a na...     False
#
#                                           external_urls  \
# 2261  {'spotify': 'https://open.spotify.com/show/6wm...
#
#                                                    href  \
# 2261  https://api.spotify.com/v1/shows/6wmqpNulHEqJN...
#
#                           id  \
# 2261  6wmqpNulHEqJNeR2iqmgyj
#
#                                                  images  is_externally_hosted  \
# 2261  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 False
#
#      languages media_type                name       publisher  type  \
# 2261   [en-US]      audio  Brooke and Jeffrey  iHeartPodcasts  show
#
#                                       uri  total_episodes   query
# 2261  spotify:show:6wmqpNulHEqJNeR2iqmgyj         10958.0  comedy

# %% [markdown]
# iHeartPodcasts has more than 10k episodes

# %%
new_releases_df["release_date"].max()
# Out:
# '2024-04-19'

# %%
# Categorical analysis
artists_df["genres"].explode().value_counts().head(10)
# Out:
# genres
# east coast hip hop     59
# old school hip hop     41
# underground hip hop    36
# hip hop                31
# boom bap               30
# jazz rap               27
# v-pop                  26
# vietnamese hip hop     25
# german hip hop         25
# christian hip hop      23
# Name: count, dtype: int64

# %%
# engagement metrics
# top 10 tracks by streams
tracks_df[["name", "artists", "popularity", "duration_ms"]].sort_values("popularity", ascending=False).head(10)
# Out:
#                                             name  \
# 81                         Juicy - 2005 Remaster
# 38                                    Thong Song
# 16                                       Monster
# 2    Jukebox Joints (feat. Joe Fox & Kanye West)
# 10                 Lonely Road (with Jelly Roll)
# 350                               Family Matters
# 251                               Family Matters
# 164                                      Yeniden
# 216                                      Yeniden
# 100                                   Thong Song
#
#                                                artists  popularity  \
# 81   [{'external_urls': {'spotify': 'https://open.s...          76
# 38   [{'external_urls': {'spotify': 'https://open.s...          76
# 16   [{'external_urls': {'spotify': 'https://open.s...          75
# 2    [{'external_urls': {'spotify': 'https://open.s...          75
# 10   [{'external_urls': {'spotify': 'https://open.s...          74
# 350  [{'external_urls': {'spotify': 'https://open.s...          71
# 251  [{'external_urls': {'spotify': 'https://open.s...          71
# 164  [{'external_urls': {'spotify': 'https://open.s...          71
# 216  [{'external_urls': {'spotify': 'https://open.s...          71
# 100  [{'external_urls': {'spotify': 'https://open.s...          71
#
#      duration_ms
# 81        302760
# 38        253733
# 16        378893
# 2         323962
# 10        189356
# 350       456933
# 251       456933
# 164       220207
# 216       220207
# 100       180966

# %%
podcast_details_df.iloc[148, 0:]
# Out:
# available_markets       [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# copyrights                                                             []
# description             The Ramsey Show Highlights is a quick, daily d...
# html_description        <p>The Ramsey Show Highlights is a quick, dail...
# explicit                                                            False
# external_urls           {'spotify': 'https://open.spotify.com/show/0O9...
# href                    https://api.spotify.com/v1/shows/0O9DsvFgkkzp7...
# id                                                 0O9DsvFgkkzp7Ze60R2JrV
# images                  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# is_externally_hosted                                                False
# languages                                                            [en]
# media_type                                                          mixed
# name                                           The Ramsey Show Highlights
# publisher                                                  Ramsey Network
# type                                                                 show
# uri                                   spotify:show:0O9DsvFgkkzp7Ze60R2JrV
# total_episodes                                                       2647
# episodes                {'href': 'https://api.spotify.com/v1/shows/0O9...
# Name: 148, dtype: object

# %%
podcast_details_df.head()
# Out:
#                                    available_markets copyrights  \
# 0  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...         []
# 1  [AD, AE, AG, AL, AM, AR, AT, AU, BA, BB, BE, B...         []
# 2  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...         []
# 3  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...         []
# 4  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...         []
#
#                                          description  \
# 0  Listen for a comprehensive audio report on tod...
# 1  Covering Geopolitical News from around the world.
# 2  Seeking Alpha's flagship Wall Street Breakfast...
# 3  Business of Home's host Dennis Scully intervie...
# 4  Learn how companies work from the people who k...
#
#                                     html_description  explicit  \
# 0  <p>Listen for a comprehensive audio report on ...     False
# 1  Covering Geopolitical News from around the world.      True
# 2  Seeking Alpha&#39;s flagship Wall Street Break...     False
# 3  Business of Home&#39;s host Dennis Scully inte...     False
# 4  <p>Learn how companies work from the people wh...     False
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/show/5q8...
# 1  {'spotify': 'https://open.spotify.com/show/1Tm...
# 2  {'spotify': 'https://open.spotify.com/show/05u...
# 3  {'spotify': 'https://open.spotify.com/show/44R...
# 4  {'spotify': 'https://open.spotify.com/show/417...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/shows/5q8wg5rFYbbeD...  5q8wg5rFYbbeDk0kk7t6Uc
# 1  https://api.spotify.com/v1/shows/1Tm6Snolm6lrP...  1Tm6Snolm6lrPhqJcbaYTt
# 2  https://api.spotify.com/v1/shows/05uLjJxkVgQsR...  05uLjJxkVgQsRk8LWLCLpx
# 3  https://api.spotify.com/v1/shows/44REgaXjBseF4...  44REgaXjBseF4ZanktPyjL
# 4  https://api.spotify.com/v1/shows/417NPBWqtMbDU...  417NPBWqtMbDU0FlWZTRDC
#
#                                               images  is_externally_hosted  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 False
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 False
# 2  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 False
# 3  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 False
# 4  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 False
#
#   languages media_type                      name  \
# 0   [en-US]      audio        Bloomberg News Now
# 1      [en]      mixed           Business Basics
# 2      [en]      audio     Wall Street Breakfast
# 3      [en]      audio  Business of Home Podcast
# 4      [en]      mixed       Business Breakdowns
#
#                                   publisher  type  \
# 0                                 Bloomberg  show
# 1                           Business Basics  show
# 2                             Seeking Alpha  show
# 3           Business of Home, Dennis Scully  show
# 4  Colossus | Investing & Business Podcasts  show
#
#                                    uri  total_episodes  \
# 0  spotify:show:5q8wg5rFYbbeDk0kk7t6Uc             901
# 1  spotify:show:1Tm6Snolm6lrPhqJcbaYTt             326
# 2  spotify:show:05uLjJxkVgQsRk8LWLCLpx            1000
# 3  spotify:show:44REgaXjBseF4ZanktPyjL             528
# 4  spotify:show:417NPBWqtMbDU0FlWZTRDC             251
#
#                                             episodes
# 0  {'href': 'https://api.spotify.com/v1/shows/5q8...
# 1  {'href': 'https://api.spotify.com/v1/shows/1Tm...
# 2  {'href': 'https://api.spotify.com/v1/shows/05u...
# 3  {'href': 'https://api.spotify.com/v1/shows/44R...
# 4  {'href': 'https://api.spotify.com/v1/shows/417...

# %%
playlist_details_df.head(1)
# Out:
#   collaborative description  \
# 0         False
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/playlist...
#
#                          followers  \
# 0  {'href': None, 'total': 214971}
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/playlists/327k1ryJ7...  327k1ryJ7j1xD7gWKpdc6o
#
#                                               images                     name  \
# 0  [{'height': 640, 'url': 'https://mosaic.scdn.c...  Popular Christian Music
#
#                                                owner  primary_color public  \
# 0  {'display_name': 'Juliann Hale', 'external_url...            NaN   True
#
#                         snapshot_id  \
# 0  AAABTkI5wd2y1BmM+Eu9hBpkTCkrhakz
#
#                                               tracks      type  \
# 0  {'href': 'https://api.spotify.com/v1/playlists...  playlist
#
#                                        uri error
# 0  spotify:playlist:327k1ryJ7j1xD7gWKpdc6o   NaN

# %%
playlist_details_df['followers_total'] = playlist_details_df['followers'].apply(
    lambda x: x['total'] if isinstance(x, dict) and 'total' in x else 0
)

playlist_details_df['tracks_total'] = playlist_details_df['tracks'].apply(
    lambda x: x['total'] if isinstance(x, dict) and 'total' in x else 0
)


# Check
playlist_details_df[['followers_total']].head()
# Out:
#    followers_total
# 0           214971
# 1            73005
# 2            77141
# 3            73892
# 4           664175

# %%
# relationship correlation

playlist_details_df_copy = playlist_details_df.copy()
playlist_details_df_copy['followers_total'] = playlist_details_df_copy['followers'].apply(
    lambda x: x['total'] if isinstance(x, dict) and 'total' in x else 0
)

playlist_details_df_copy['tracks_total'] = playlist_details_df_copy['tracks'].apply(
    lambda x: x['total'] if isinstance(x, dict) and 'total' in x else 0
)

playlist_details_df_copy[['followers_total','tracks_total']].corr()
# Out:
#                  followers_total  tracks_total
# followers_total         1.000000      0.046391
# tracks_total            0.046391      1.000000

# %% [markdown]
# longer playlists might attract slightly more engagement, which could impact ad revenue, but it’s not the dominant driver
